# %% [markdown]
# ## 1. The World Bank's international debt data
# <p>It's not that we humans only take debts to manage our necessities. A country may also take debt to manage its economy. For example, infrastructure spending is one costly ingredient required for a country's citizens to lead comfortable lives. <a href="https://www.worldbank.org">The World Bank</a> is the organization that provides debt to countries.</p>
# <p>In this notebook, we are going to analyze international debt data collected by The World Bank. The dataset contains information about the amount of debt (in USD) owed by developing countries across several categories. We are going to find the answers to questions like: </p>
# <ul>
# <li>What is the total amount of debt that is owed by the countries listed in the dataset?</li>
# <li>Which country owns the maximum amount of debt and what does that amount look like?</li>
# <li>What is the average amount of debt owed by countries across different debt indicators?</li>
# </ul>
# <p><img src="https://assets.datacamp.com/production/project_754/img/image.jpg" alt></p>
# <p>The first line of code connects us to the <code>international_debt</code> database where the table <code>international_debt</code> is residing. Let's first <code>SELECT</code> <em>all</em> of the columns from the <code>international_debt</code> table. Also, we'll limit the output to the first ten rows to keep the output clean.</p>

# %%
# %%sql
# postgresql:///international_debt
#     SELECT *
#     FROM international_debt
#     LIMIT 10
# Out:
# 10 rows affected.
# [('Afghanistan', 'AFG', 'Disbursements on external debt, long-term (DIS, current US$)', 'DT.DIS.DLXF.CD', Decimal('72894453.700000003')),
#  ('Afghanistan', 'AFG', 'Interest payments on external debt, long-term (INT, current US$)', 'DT.INT.DLXF.CD', Decimal('53239440.100000001')),
#  ('Afghanistan', 'AFG', 'PPG, bilateral (AMT, current US$)', 'DT.AMT.BLAT.CD', Decimal('61739336.899999999')),
#  ('Afghanistan', 'AFG', 'PPG, bilateral (DIS, current US$)', 'DT.DIS.BLAT.CD', Decimal('49114729.399999999')),
#  ('Afghanistan', 'AFG', 'PPG, bilateral (INT, current US$)', 'DT.INT.BLAT.CD', Decimal('39903620.100000001')),
#  ('Afghanistan', 'AFG', 'PPG, multilateral (AMT, current US$)', 'DT.AMT.MLAT.CD', Decimal('39107845')),
#  ('Afghanistan', 'AFG', 'PPG, multilateral (DIS, current US$)', 'DT.DIS.MLAT.CD', Decimal('23779724.300000001')),
#  ('Afghanistan', 'AFG', 'PPG, multilateral (INT, current US$)', 'DT.INT.MLAT.CD', Decimal('13335820')),
#  ('Afghanistan', 'AFG', 'PPG, official creditors (AMT, current US$)', 'DT.AMT.OFFT.CD', Decimal('100847181.900000006')),
#  ('Afghanistan', 'AFG', 'PPG, official creditors (DIS, current US$)', 'DT.DIS.OFFT.CD', Decimal('72894453.700000003'))]

# %% [markdown]
# ## 2. Finding the number of distinct countries
# <p>From the first ten rows, we can see the amount of debt owed by <em>Afghanistan</em> in the different debt indicators. But we do not know the number of different countries we have on the table. There are repetitions in the country names because a country is most likely to have debt in more than one debt indicator. </p>
# <p>Without a count of unique countries, we will not be able to perform our statistical analyses holistically. In this section, we are going to extract the number of unique countries present in the table. </p>

# %%
# %%sql
# SELECT
#     COUNT (DISTINCT country_name) AS total_distinct_countries
# FROM international_debt;
# Out:
#  * postgresql:///international_debt
# 1 rows affected.
# [(124,)]

# %% [markdown]
# ## 3. Finding out the distinct debt indicators
# <p>We can see there are a total of 124 countries present on the table. As we saw in the first section, there is a column called <code>indicator_name</code> that briefly specifies the purpose of taking the debt. Just beside that column, there is another column called <code>indicator_code</code> which symbolizes the category of these debts. Knowing about these various debt indicators will help us to understand the areas in which a country can possibly be indebted to. </p>

# %%
# %%sql
# SELECT DISTINCT indicator_code AS distinct_debt_indicators
# FROM international_debt
# ORDER BY distinct_debt_indicators
# Out:
#  * postgresql:///international_debt
# 25 rows affected.
# [('DT.AMT.BLAT.CD',),
#  ('DT.AMT.DLXF.CD',),
#  ('DT.AMT.DPNG.CD',),
#  ('DT.AMT.MLAT.CD',),
#  ('DT.AMT.OFFT.CD',),
#  ('DT.AMT.PBND.CD',),
#  ('DT.AMT.PCBK.CD',),
#  ('DT.AMT.PROP.CD',),
#  ('DT.AMT.PRVT.CD',),
#  ('DT.DIS.BLAT.CD',),
#  ('DT.DIS.DLXF.CD',),
#  ('DT.DIS.MLAT.CD',),
#  ('DT.DIS.OFFT.CD',),
#  ('DT.DIS.PCBK.CD',),
#  ('DT.DIS.PROP.CD',),
#  ('DT.DIS.PRVT.CD',),
#  ('DT.INT.BLAT.CD',),
#  ('DT.INT.DLXF.CD',),
#  ('DT.INT.DPNG.CD',),
#  ('DT.INT.MLAT.CD',),
#  ('DT.INT.OFFT.CD',),
#  ('DT.INT.PBND.CD',),
#  ('DT.INT.PCBK.CD',),
#  ('DT.INT.PROP.CD',),
#  ('DT.INT.PRVT.CD',)]

# %% [markdown]
# ## 4. Totaling the amount of debt owed by the countries
# <p>As mentioned earlier, the financial debt of a particular country represents its economic state. But if we were to project this on an overall global scale, how will we approach it?</p>
# <p>Let's switch gears from the debt indicators now and find out the total amount of debt (in USD) that is owed by the different countries. This will give us a sense of how the overall economy of the entire world is holding up.</p>

# %%
# %%sql
# SELECT
#     ROUND((SUM (debt))/1000000,2) AS total_debt
# FROM international_debt;
# Out:
#  * postgresql:///international_debt
# 1 rows affected.
# [(Decimal('3079734.49'),)]

# %% [markdown]
# ## 5. Country with the highest debt
# <p>"Human beings cannot comprehend very large or very small numbers. It would be useful for us to acknowledge that fact." - <a href="https://en.wikipedia.org/wiki/Daniel_Kahneman">Daniel Kahneman</a>. That is more than <em>3 million <strong>million</strong></em> USD, an amount which is really hard for us to fathom. </p>
# <p>Now that we have the exact total of the amounts of debt owed by several countries, let's now find out the country that owns the highest amount of debt along with the amount. <strong>Note</strong> that this debt is the sum of different debts owed by a country across several categories. This will help to understand more about the country in terms of its socio-economic scenarios. We can also find out the category in which the country owns its highest debt. But we will leave that for now. </p>

# %%
# %%sql
# SELECT
#     country_name, SUM(debt) AS total_debt
# FROM international_debt
# GROUP BY country_name
# ORDER BY total_debt DESC
# LIMIT 1;
# Out:
#  * postgresql:///international_debt
# 1 rows affected.
# [('China', Decimal('285793494734.200001568'))]

# %% [markdown]
# ## 6. Average amount of debt across indicators
# <p>So, it was <em>China</em>. A more in-depth breakdown of China's debts can be found <a href="https://datatopics.worldbank.org/debt/ids/country/CHN">here</a>. </p>
# <p>We now have a brief overview of the dataset and a few of its summary statistics. We already have an idea of the different debt indicators in which the countries owe their debts. We can dig even further to find out on an average how much debt a country owes? This will give us a better sense of the distribution of the amount of debt across different indicators.</p>

# %%
# %%sql
# SELECT indicator_code AS debt_indicator, indicator_name, AVG(debt) AS average_debt
# FROM international_debt
# GROUP BY debt_indicator, indicator_name
# ORDER BY average_debt DESC
# LIMIT 10
# Out:
#  * postgresql:///international_debt
# 10 rows affected.
# [('DT.AMT.DLXF.CD', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('5904868401.499193612')),
#  ('DT.AMT.DPNG.CD', 'Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)', Decimal('5161194333.812658349')),
#  ('DT.DIS.DLXF.CD', 'Disbursements on external debt, long-term (DIS, current US$)', Decimal('2152041216.890243888')),
#  ('DT.DIS.OFFT.CD', 'PPG, official creditors (DIS, current US$)', Decimal('1958983452.859836046')),
#  ('DT.AMT.PRVT.CD', 'PPG, private creditors (AMT, current US$)', Decimal('1803694101.963265321')),
#  ('DT.INT.DLXF.CD', 'Interest payments on external debt, long-term (INT, current US$)', Decimal('1644024067.650806481')),
#  ('DT.DIS.BLAT.CD', 'PPG, bilateral (DIS, current US$)', Decimal('1223139290.398230108')),
#  ('DT.INT.DPNG.CD', 'Interest payments on external debt, private nonguaranteed (PNG) (INT, current US$)', Decimal('1220410844.421518983')),
#  ('DT.AMT.OFFT.CD', 'PPG, official creditors (AMT, current US$)', Decimal('1191187963.083064523')),
#  ('DT.AMT.PBND.CD', 'PPG, bonds (AMT, current US$)', Decimal('1082623947.653623188'))]

# %% [markdown]
# ## 7. The highest amount of principal repayments
# <p>We can see that the indicator <code>DT.AMT.DLXF.CD</code> tops the chart of average debt. This category includes repayment of long term debts. Countries take on long-term debt to acquire immediate capital. More information about this category can be found <a href="https://datacatalog.worldbank.org/principal-repayments-external-debt-long-term-amt-current-us-0">here</a>. </p>
# <p>An interesting observation in the above finding is that there is a huge difference in the amounts of the indicators after the second one. This indicates that the first two indicators might be the most severe categories in which the countries owe their debts.</p>
# <p>We can investigate this a bit more so as to find out which country owes the highest amount of debt in the category of long term debts (<code>DT.AMT.DLXF.CD</code>). Since not all the countries suffer from the same kind of economic disturbances, this finding will allow us to understand that particular country's economic condition a bit more specifically. </p>

# %%
# %%sql
# SELECT country_name, indicator_name
# FROM international_debt
# WHERE debt = (SELECT MAX(debt)
# FROM international_debt
# WHERE indicator_code = 'DT.AMT.DLXF.CD' )
# Out:
#  * postgresql:///international_debt
# 1 rows affected.
# [('China', 'Principal repayments on external debt, long-term (AMT, current US$)')]

# %% [markdown]
# ## 8. The most common debt indicator
# <p>China has the highest amount of debt in the long-term debt (<code>DT.AMT.DLXF.CD</code>) category. This is verified by <a href="https://data.worldbank.org/indicator/DT.AMT.DLXF.CD?end=2018&most_recent_value_desc=true">The World Bank</a>. It is often a good idea to verify our analyses like this since it validates that our investigations are correct. </p>
# <p>We saw that long-term debt is the topmost category when it comes to the average amount of debt. But is it the most common indicator in which the countries owe their debt? Let's find that out. </p>

# %%
# %%sql
# SELECT indicator_Code, COUNT (indicator_code) AS indicator_count
# FROM international_debt
# GROUP BY indicator_code
# ORDER BY indicator_count DESC
# LIMIT 20
# Out:
#  * postgresql:///international_debt
# 20 rows affected.
# [('DT.INT.MLAT.CD', 124),
#  ('DT.AMT.OFFT.CD', 124),
#  ('DT.INT.DLXF.CD', 124),
#  ('DT.AMT.MLAT.CD', 124),
#  ('DT.AMT.DLXF.CD', 124),
#  ('DT.INT.OFFT.CD', 124),
#  ('DT.DIS.DLXF.CD', 123),
#  ('DT.DIS.OFFT.CD', 122),
#  ('DT.INT.BLAT.CD', 122),
#  ('DT.AMT.BLAT.CD', 122),
#  ('DT.DIS.MLAT.CD', 120),
#  ('DT.DIS.BLAT.CD', 113),
#  ('DT.INT.PRVT.CD', 98),
#  ('DT.AMT.PRVT.CD', 98),
#  ('DT.AMT.PCBK.CD', 84),
#  ('DT.INT.PCBK.CD', 84),
#  ('DT.INT.DPNG.CD', 79),
#  ('DT.AMT.DPNG.CD', 79),
#  ('DT.INT.PBND.CD', 69),
#  ('DT.AMT.PBND.CD', 69)]

# %% [markdown]
# ## 9. Other viable debt issues and conclusion
# <p>There are a total of six debt indicators in which all the countries listed in our dataset have taken debt. The indicator <code>DT.AMT.DLXF.CD</code> is also there in the list. So, this gives us a clue that all these countries are suffering from a common economic issue. But that is not the end of the story, but just a part of the story.</p>
# <p>Let's change tracks from <code>debt_indicator</code>s now and focus on the amount of debt again. Let's find out the maximum amount of debt that each country has. With this, we will be in a position to identify the other plausible economic issues a country might be going through.</p>
# <p>In this notebook, we took a look at debt owed by countries across the globe. We extracted a few summary statistics from the data and unraveled some interesting facts and figures. We also validated our findings to make sure the investigations are correct.</p>

# %%
# %%sql
# SELECT country_name,  indicator_name, MAX(debt) AS maximum_debt
# FROM international_debt
# GROUP BY country_name, indicator_name
# ORDER BY maximum_debt DESC
# Out:
#  * postgresql:///international_debt
# 2357 rows affected.
# [('China', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('96218620835.699996948')),
#  ('Brazil', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('90041840304.100006104')),
#  ('China', 'Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)', Decimal('72392986213.800003052')),
#  ('Russian Federation', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('66589761833.5')),
#  ('Turkey', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('51555031005.800003052')),
#  ('South Asia', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('48756295898.199996948')),
#  ('Brazil', 'PPG, private creditors (AMT, current US$)', Decimal('43598697498.599998474')),
#  ('Russian Federation', 'Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)', Decimal('42800154974.900001526')),
#  ('Brazil', 'Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)', Decimal('41831444053.300003052')),
#  ('Least developed countries: UN classification', 'Disbursements on external debt, long-term (DIS, current US$)', Decimal('40160766261.599998474')),
#  ('Turkey', 'Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)', Decimal('39916197430')),
#  ('Least developed countries: UN classification', 'PPG, official creditors (DIS, current US$)', Decimal('37273977350.5')),
#  ('Brazil', 'PPG, other private creditors (AMT, current US$)', Decimal('35119003750')),
#  ('IDA only', 'Disbursements on external debt, long-term (DIS, current US$)', Decimal('34531188113.199996948')),
#  ('IDA only', 'PPG, official creditors (DIS, current US$)', Decimal('33258230166.900001526')),
#  ('India', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('31923507000.799999237')),
#  ('Indonesia', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('30916112653.799999237')),
#  ('South Asia', 'Disbursements on external debt, long-term (DIS, current US$)', Decimal('29306216064.700000763')),
#  ('South Asia', 'PPG, official creditors (DIS, current US$)', Decimal('28991897351.5')),
#  ('Kazakhstan', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('27482093686.400001526')),
#  ('Kazakhstan', 'Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)', Decimal('26357360300')),
#  ('Mexico', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('25218503927')),
#  ('Least developed countries: UN classification', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('25197029299.400001526')),
#  ('South Asia', 'Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)', Decimal('24370850062.400001526')),
#  ('Russian Federation', 'PPG, private creditors (AMT, current US$)', Decimal('23578013136.400001526')),
#  ('Least developed countries: UN classification', 'PPG, bilateral (DIS, current US$)', Decimal('23333956388.400001526')),
#  ('Russian Federation', 'PPG, commercial banks (AMT, current US$)', Decimal('22077398848.099998474')),
#  ('IDA only', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('20483289208')),
#  ('India', 'Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)', Decimal('20307068620')),
#  ('Mexico', 'Interest payments on external debt, long-term (INT, current US$)', Decimal('19267966623.400001526')),
#  ('Indonesia', 'Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)', Decimal('18643874810')),
#  ('Mexico', 'PPG, private creditors (AMT, current US$)', Decimal('18632526634.400001526')),
#  ('Cameroon', 'Disbursements on external debt, long-term (DIS, current US$)', Decimal('18186662060.400001526')),
#  ('Cameroon', 'PPG, official creditors (DIS, current US$)', Decimal('17940581035.599998474')),
#  ('China', 'Interest payments on external debt, long-term (INT, current US$)', Decimal('17866548651.400001526')),
#  ('South Asia', 'PPG, bilateral (DIS, current US$)', Decimal('17269114040.900001526')),
#  ('Mexico', 'PPG, bonds (AMT, current US$)', Decimal('17109552312.5')),
#  ('Cameroon', 'PPG, bilateral (DIS, current US$)', Decimal('17090544247.5')),
#  ('Least developed countries: UN classification', 'PPG, official creditors (AMT, current US$)', Decimal('17028978560.799999237')),
#  ('Brazil', 'Interest payments on external debt, long-term (INT, current US$)', Decimal('17001653109.200000763')),
#  ('IDA only', 'PPG, bilateral (DIS, current US$)', Decimal('16882903064.399999619')),
#  ('IDA only', 'PPG, multilateral (DIS, current US$)', Decimal('16375327102.5')),
#  ('South Asia', 'Interest payments on external debt, long-term (INT, current US$)', Decimal('15931560388.100000381')),
#  ('China', 'Disbursements on external debt, long-term (DIS, current US$)', Decimal('15692563746.100000381')),
#  ('China', 'PPG, private creditors (AMT, current US$)', Decimal('14677464465.899999619')),
#  ('South Asia', 'PPG, official creditors (AMT, current US$)', Decimal('14289544377.600000381')),
#  ('China', 'Interest payments on external debt, private nonguaranteed (PNG) (INT, current US$)', Decimal('14142718751.600000381')),
#  ('Romania', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('14013783350.399999619')),
#  ('Least developed countries: UN classification', 'PPG, multilateral (DIS, current US$)', Decimal('13940020962.100000381')),
#  ('Russian Federation', 'Interest payments on external debt, long-term (INT, current US$)', Decimal('13929825315.600000381')),
#  ('Mexico', 'PPG, private creditors (INT, current US$)', Decimal('13131634472.899999619')),
#  ('Least developed countries: UN classification', 'PPG, bilateral (AMT, current US$)', Decimal('12944703036.600000381')),
#  ('Mexico', 'PPG, bonds (INT, current US$)', Decimal('12310714652.799999237')),
#  ('Turkey', 'Interest payments on external debt, long-term (INT, current US$)', Decimal('12095568642.200000763')),
#  ('Colombia', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('11985674438.700000763')),
#  ('South Asia', 'PPG, multilateral (DIS, current US$)', Decimal('11722783310.600000381')),
#  ('India', 'Interest payments on external debt, long-term (INT, current US$)', Decimal('11419475865.799999237')),
#  ('IDA only', 'PPG, official creditors (AMT, current US$)', Decimal('11157576571.100000381')),
#  ('Angola', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('11067045628.100000381')),
#  ('India', 'Disbursements on external debt, long-term (DIS, current US$)', Decimal('11005547326.200000763')),
#  ('Brazil', 'Interest payments on external debt, private nonguaranteed (PNG) (INT, current US$)', Decimal('10952236000')),
#  ('Angola', 'Disbursements on external debt, long-term (DIS, current US$)', Decimal('10924018093.100000381')),
#  ('India', 'PPG, official creditors (DIS, current US$)', Decimal('10922019579.899999619')),
#  ('Cameroon', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('10404814960.200000763')),
#  ('Romania', 'Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)', Decimal('10300588995.700000763')),
#  ('Indonesia', 'Interest payments on external debt, long-term (INT, current US$)', Decimal('10190097793.799999237')),
#  ('Cameroon', 'PPG, official creditors (AMT, current US$)', Decimal('10152021121.399999619')),
#  ('South Asia', 'PPG, private creditors (AMT, current US$)', Decimal('10095901458.200000763')),
#  ('Cameroon', 'PPG, bilateral (AMT, current US$)', Decimal('9999925153.299999237')),
#  ('Venezuela, RB', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('9878659207.200000763')),
#  ('China', 'PPG, bonds (AMT, current US$)', Decimal('9834677000')),
#  ('South Asia', 'Interest payments on external debt, private nonguaranteed (PNG) (INT, current US$)', Decimal('9813113000')),
#  ('Egypt, Arab Rep.', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('9692114176.899999619')),
#  ('Egypt, Arab Rep.', 'Disbursements on external debt, long-term (DIS, current US$)', Decimal('9552207423.5')),
#  ('Lebanon', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('9506919669.600000381')),
#  ('South Africa', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('9474257551.899999619')),
#  ('Egypt, Arab Rep.', 'PPG, official creditors (AMT, current US$)', Decimal('9374088398.5')),
#  ('Egypt, Arab Rep.', 'PPG, official creditors (DIS, current US$)', Decimal('9355743701.899999619')),
#  ('China', 'PPG, official creditors (AMT, current US$)', Decimal('9148170156')),
#  ('India', 'Interest payments on external debt, private nonguaranteed (PNG) (INT, current US$)', Decimal('9111461000')),
#  ('Bangladesh', 'Disbursements on external debt, long-term (DIS, current US$)', Decimal('9050557611.899999619')),
#  ('Bangladesh', 'PPG, official creditors (DIS, current US$)', Decimal('9050557611.899999619')),
#  ('Angola', 'PPG, official creditors (DIS, current US$)', Decimal('9017246499.299999237')),
#  ('Vietnam', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('8873505909.200000763')),
#  ('Angola', 'PPG, bilateral (DIS, current US$)', Decimal('8838256901.100000381')),
#  ('Angola', 'PPG, official creditors (AMT, current US$)', Decimal('8598512708.200000763')),
#  ('Angola', 'PPG, bilateral (AMT, current US$)', Decimal('8473824016.300000191')),
#  ('Pakistan', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('8336013891.300000191')),
#  ('Ukraine', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('8148995625.600000381')),
#  ('Turkey', 'PPG, private creditors (AMT, current US$)', Decimal('8059671018')),
#  ('South Asia', 'PPG, multilateral (AMT, current US$)', Decimal('7851739929.5')),
#  ('Russian Federation', 'Interest payments on external debt, private nonguaranteed (PNG) (INT, current US$)', Decimal('7568679036.399999619')),
#  ('Turkey', 'Interest payments on external debt, private nonguaranteed (PNG) (INT, current US$)', Decimal('7453172920')),
#  ('Egypt, Arab Rep.', 'PPG, bilateral (DIS, current US$)', Decimal('7275502144.399999619')),
#  ('IDA only', 'Interest payments on external debt, long-term (INT, current US$)', Decimal('7269408633.800000191')),
#  ('Least developed countries: UN classification', 'Interest payments on external debt, long-term (INT, current US$)', Decimal('7085064805.199999809')),
#  ('India', 'PPG, official creditors (AMT, current US$)', Decimal('6997605744.399999619')),
#  ('Egypt, Arab Rep.', 'PPG, bilateral (AMT, current US$)', Decimal('6949184320.5')),
#  ('South Africa', 'Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)', Decimal('6685515858.399999619')),
#  ('Indonesia', 'PPG, private creditors (AMT, current US$)', Decimal('6569655825.199999809')),
#  ('Brazil', 'PPG, commercial banks (AMT, current US$)', Decimal('6538835248.600000381')),
#  ('China', 'PPG, bilateral (AMT, current US$)', Decimal('6532446441.899999619')),
#  ('Venezuela, RB', 'Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)', Decimal('6517487000')),
#  ('Lebanon', 'Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)', Decimal('6514899000')),
#  ('Turkey', 'PPG, bonds (AMT, current US$)', Decimal('6499125000')),
#  ('Vietnam', 'Disbursements on external debt, long-term (DIS, current US$)', Decimal('6494121653.199999809')),
#  ('Philippines', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('6479170917.699999809')),
#  ('Vietnam', 'PPG, official creditors (DIS, current US$)', Decimal('6468774725.399999619')),
#  ('IDA only', 'Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)', Decimal('6439587318')),
#  ('South Asia', 'PPG, bilateral (AMT, current US$)', Decimal('6437804448.100000381')),
#  ('Russian Federation', 'PPG, private creditors (INT, current US$)', Decimal('6341914863.300000191')),
#  ('IDA only', 'PPG, bilateral (AMT, current US$)', Decimal('6273480947.800000191')),
#  ('Bangladesh', 'PPG, bilateral (DIS, current US$)', Decimal('6141785637.5')),
#  ('Thailand', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('5914706998.300000191')),
#  ('Peru', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('5881259974.699999809')),
#  ('Sri Lanka', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('5761489255.899999619')),
#  ('Indonesia', 'PPG, official creditors (AMT, current US$)', Decimal('5702582018.600000381')),
#  ('Vietnam', 'Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)', Decimal('5646513000')),
#  ('Thailand', 'Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)', Decimal('5597835810')),
#  ('India', 'PPG, bilateral (DIS, current US$)', Decimal('5588550763.399999619')),
#  ('Colombia', 'PPG, private creditors (AMT, current US$)', Decimal('5527915801')),
#  ('Mexico', 'Interest payments on external debt, private nonguaranteed (PNG) (INT, current US$)', Decimal('5466172888.199999809')),
#  ('Indonesia', 'PPG, private creditors (INT, current US$)', Decimal('5380585630.800000191')),
#  ('Mexico', 'Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)', Decimal('5339338190')),
#  ('Kazakhstan', 'Interest payments on external debt, long-term (INT, current US$)', Decimal('5333500397.899999619')),
#  ('India', 'PPG, multilateral (DIS, current US$)', Decimal('5333468816.5')),
#  ('Pakistan', 'Disbursements on external debt, long-term (DIS, current US$)', Decimal('5301166769.899999619')),
#  ('Pakistan', 'PPG, official creditors (DIS, current US$)', Decimal('5254500103.199999809')),
#  ('Indonesia', 'PPG, bonds (INT, current US$)', Decimal('5232651353.5')),
#  ('Morocco', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('5153430846.800000191')),
#  ('Brazil', 'PPG, private creditors (INT, current US$)', Decimal('5010149983.399999619')),
#  ('South Asia', 'PPG, commercial banks (AMT, current US$)', Decimal('5004801917.300000191')),
#  ('Colombia', 'Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)', Decimal('4909293190')),
#  ('IDA only', 'PPG, multilateral (AMT, current US$)', Decimal('4884095623.300000191')),
#  ('South Asia', 'PPG, bonds (AMT, current US$)', Decimal('4883333333.300000191')),
#  ('South Africa', 'Interest payments on external debt, long-term (INT, current US$)', Decimal('4872276053.399999619')),
#  ('Ukraine', 'Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)', Decimal('4844593101.5')),
#  ('Peru', 'Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)', Decimal('4817310190')),
#  ('Belarus', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('4640037884.199999809')),
#  ('India', 'PPG, private creditors (AMT, current US$)', Decimal('4618832636.399999619')),
#  ('Brazil', 'PPG, official creditors (AMT, current US$)', Decimal('4611698752.199999809')),
#  ('Colombia', 'Interest payments on external debt, long-term (INT, current US$)', Decimal('4564574602.100000381')),
#  ('Kazakhstan', 'Interest payments on external debt, private nonguaranteed (PNG) (INT, current US$)', Decimal('4552173000')),
#  ('India', 'PPG, multilateral (AMT, current US$)', Decimal('4545609909.899999619')),
#  ('Least developed countries: UN classification', 'PPG, private creditors (AMT, current US$)', Decimal('4486734431.899999619')),
#  ('Least developed countries: UN classification', 'PPG, official creditors (INT, current US$)', Decimal('4426494528.600000381')),
#  ('Colombia', 'PPG, bonds (AMT, current US$)', Decimal('4398582816.699999809')),
#  ('Kenya', 'Disbursements on external debt, long-term (DIS, current US$)', Decimal('4266494939.699999809')),
#  ('Russian Federation', 'PPG, commercial banks (INT, current US$)', Decimal('4228747124.800000191')),
#  ('Indonesia', 'Disbursements on external debt, long-term (DIS, current US$)', Decimal('4177287375.800000191')),
#  ('Venezuela, RB', 'Interest payments on external debt, long-term (INT, current US$)', Decimal('4159342365.599999905')),
#  ('Vietnam', 'PPG, bilateral (DIS, current US$)', Decimal('4134438674.800000191')),
#  ('Indonesia', 'PPG, bonds (AMT, current US$)', Decimal('4114167404.800000191')),
#  ('China', 'PPG, private creditors (DIS, current US$)', Decimal('4111062474')),
#  ('IDA only', 'PPG, official creditors (INT, current US$)', Decimal('4106854487.400000095')),
#  ('Brazil', 'Disbursements on external debt, long-term (DIS, current US$)', Decimal('4092388651.400000095')),
#  ('Least developed countries: UN classification', 'PPG, multilateral (AMT, current US$)', Decimal('4084275524.199999809')),
#  ('China', 'PPG, commercial banks (AMT, current US$)', Decimal('4046243298.5')),
#  ('Turkey', 'PPG, private creditors (INT, current US$)', Decimal('4007367753.599999905')),
#  ('South Asia', 'PPG, official creditors (INT, current US$)', Decimal('3920350393.099999905')),
#  ('Philippines', 'Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)', Decimal('3899637459.900000095')),
#  ('South Africa', 'PPG, private creditors (INT, current US$)', Decimal('3832448818.099999905')),
#  ('Turkey', 'PPG, bonds (INT, current US$)', Decimal('3786751212')),
#  ('China', 'PPG, commercial banks (DIS, current US$)', Decimal('3777050273.300000191')),
#  ('Indonesia', 'Interest payments on external debt, private nonguaranteed (PNG) (INT, current US$)', Decimal('3770921966.699999809')),
#  ('South Africa', 'PPG, bonds (INT, current US$)', Decimal('3766186000')),
#  ('Pakistan', 'PPG, official creditors (AMT, current US$)', Decimal('3754135338.400000095')),
#  ('Least developed countries: UN classification', 'Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)', Decimal('3681316306.699999809')),
#  ('Ecuador', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('3623731570.199999809')),
#  ('Turkey', 'PPG, official creditors (AMT, current US$)', Decimal('3579162557.800000191')),
#  ('Indonesia', 'PPG, official creditors (DIS, current US$)', Decimal('3503677320.5')),
#  ('India', 'PPG, commercial banks (AMT, current US$)', Decimal('3483945853.099999905')),
#  ('Kenya', 'PPG, official creditors (DIS, current US$)', Decimal('3423637756.300000191')),
#  ('Serbia', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('3409673950')),
#  ('Mongolia', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('3296470965.599999905')),
#  ('Pakistan', 'PPG, bilateral (DIS, current US$)', Decimal('3281555124')),
#  ('Indonesia', 'PPG, bilateral (AMT, current US$)', Decimal('3233436193.900000095')),
#  ('Brazil', 'PPG, official creditors (DIS, current US$)', Decimal('3128238798.599999905')),
#  ('Mongolia', 'Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)', Decimal('3088374276.199999809')),
#  ('Georgia', 'Interest payments on external debt, long-term (INT, current US$)', Decimal('3087990080.300000191')),
#  ('China', 'PPG, official creditors (DIS, current US$)', Decimal('3079501272.099999905')),
#  ('China', 'PPG, multilateral (DIS, current US$)', Decimal('3079501272.099999905')),
#  ('Least developed countries: UN classification', 'PPG, bilateral (INT, current US$)', Decimal('3029826352.300000191')),
#  ('Pakistan', 'PPG, private creditors (AMT, current US$)', Decimal('3021637742.900000095')),
#  ('Ukraine', 'Interest payments on external debt, long-term (INT, current US$)', Decimal('3001506404.400000095')),
#  ('Nigeria', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('2957693969.5')),
#  ('Turkey', 'PPG, multilateral (AMT, current US$)', Decimal('2932698678')),
#  ('Guatemala', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('2911981987.800000191')),
#  ('Bangladesh', 'PPG, multilateral (DIS, current US$)', Decimal('2908771974.400000095')),
#  ('Romania', 'Interest payments on external debt, long-term (INT, current US$)', Decimal('2906875294.599999905')),
#  ('Least developed countries: UN classification', 'PPG, private creditors (DIS, current US$)', Decimal('2886788911.099999905')),
#  ('IDA only', 'PPG, private creditors (AMT, current US$)', Decimal('2886125318.900000095')),
#  ('Papua New Guinea', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('2842193842.5')),
#  ('Venezuela, RB', 'PPG, private creditors (INT, current US$)', Decimal('2827938458.400000095')),
#  ('Venezuela, RB', 'PPG, bonds (INT, current US$)', Decimal('2810526000')),
#  ('Venezuela, RB', 'PPG, private creditors (AMT, current US$)', Decimal('2745605240.900000095')),
#  ('Papua New Guinea', 'Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)', Decimal('2727462849.900000095')),
#  ('Morocco', 'Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)', Decimal('2695584555.699999809')),
#  ('Lebanon', 'PPG, private creditors (AMT, current US$)', Decimal('2687252267.800000191')),
#  ('Ethiopia', 'Disbursements on external debt, long-term (DIS, current US$)', Decimal('2681493007.300000191')),
#  ('Lebanon', 'PPG, bonds (AMT, current US$)', Decimal('2653766481.099999905')),
#  ('Least developed countries: UN classification', 'PPG, commercial banks (AMT, current US$)', Decimal('2636028272.900000095')),
#  ('Least developed countries: UN classification', 'PPG, commercial banks (DIS, current US$)', Decimal('2621897864.599999905')),
#  ('China', 'PPG, multilateral (AMT, current US$)', Decimal('2615723714.099999905')),
#  ('Peru', 'Interest payments on external debt, long-term (INT, current US$)', Decimal('2592895979.300000191')),
#  ('El Salvador', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('2574548482.300000191')),
#  ('Nigeria', 'Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)', Decimal('2573685667.5')),
#  ('Venezuela, RB', 'PPG, bonds (AMT, current US$)', Decimal('2551518555.599999905')),
#  ('Brazil', 'PPG, bonds (INT, current US$)', Decimal('2550410063.199999809')),
#  ('Sri Lanka', 'Disbursements on external debt, long-term (DIS, current US$)', Decimal('2547120639.900000095')),
#  ('Colombia', 'PPG, private creditors (INT, current US$)', Decimal('2538372457.099999905')),
#  ('Guatemala', 'Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)', Decimal('2530202734.300000191')),
#  ('Belarus', 'Disbursements on external debt, long-term (DIS, current US$)', Decimal('2525227414.900000095')),
#  ('Kenya', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('2517537554.699999809')),
#  ('Turkey', 'Disbursements on external debt, long-term (DIS, current US$)', Decimal('2514443147.099999905')),
#  ('Brazil', 'PPG, multilateral (AMT, current US$)', Decimal('2514318741.599999905')),
#  ('Vietnam', 'PPG, official creditors (AMT, current US$)', Decimal('2508790752.800000191')),
#  ('Belarus', 'PPG, official creditors (DIS, current US$)', Decimal('2506830192.699999809')),
#  ('Georgia', 'PPG, official creditors (INT, current US$)', Decimal('2498637343.400000095')),
#  ('Ethiopia', 'PPG, official creditors (DIS, current US$)', Decimal('2486550684.900000095')),
#  ('Sri Lanka', 'PPG, official creditors (DIS, current US$)', Decimal('2469629011.800000191')),
#  ('Indonesia', 'PPG, multilateral (AMT, current US$)', Decimal('2469145824.699999809')),
#  ('Angola', 'PPG, private creditors (AMT, current US$)', Decimal('2468532919.900000095')),
#  ('India', 'PPG, bilateral (AMT, current US$)', Decimal('2451995834.5')),
#  ('South Africa', 'PPG, private creditors (AMT, current US$)', Decimal('2442347929.599999905')),
#  ('Georgia', 'PPG, bilateral (INT, current US$)', Decimal('2435342284.400000095')),
#  ('Sri Lanka', 'PPG, private creditors (AMT, current US$)', Decimal('2430576076')),
#  ('Egypt, Arab Rep.', 'PPG, multilateral (AMT, current US$)', Decimal('2424904078')),
#  ('Tunisia', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('2422062635.800000191')),
#  ('Colombia', 'PPG, bonds (INT, current US$)', Decimal('2362344669.400000095')),
#  ('IDA only', 'PPG, bilateral (INT, current US$)', Decimal('2351375435.800000191')),
#  ('China', 'PPG, private creditors (INT, current US$)', Decimal('2350524517.900000095')),
#  ('Vietnam', 'PPG, multilateral (DIS, current US$)', Decimal('2334336050.599999905')),
#  ('Serbia', 'Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)', Decimal('2331224601.5')),
#  ('Indonesia', 'PPG, bilateral (DIS, current US$)', Decimal('2289402723.300000191')),
#  ('Belarus', 'PPG, bilateral (DIS, current US$)', Decimal('2265336386.699999809')),
#  ('South Asia', 'PPG, private creditors (INT, current US$)', Decimal('2198096995')),
#  ('Pakistan', 'PPG, bilateral (AMT, current US$)', Decimal('2175483884.5')),
#  ('Ukraine', 'PPG, private creditors (AMT, current US$)', Decimal('2135988474.400000095')),
#  ('Lebanon', 'Interest payments on external debt, long-term (INT, current US$)', Decimal('2131942998.700000048')),
#  ('IDA only', 'PPG, commercial banks (AMT, current US$)', Decimal('2129231057.799999952')),
#  ('Morocco', 'PPG, official creditors (AMT, current US$)', Decimal('2123936462.900000095')),
#  ('Vietnam', 'Interest payments on external debt, long-term (INT, current US$)', Decimal('2120093736.299999952')),
#  ('Russian Federation', 'PPG, bonds (INT, current US$)', Decimal('2113157602.700000048')),
#  ('Bosnia and Herzegovina', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('2112748020.900000095')),
#  ('Uzbekistan', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('2097517190.900000095')),
#  ('Brazil', 'PPG, bilateral (AMT, current US$)', Decimal('2097380010.599999905')),
#  ('Belarus', 'PPG, official creditors (AMT, current US$)', Decimal('2082802104.5')),
#  ('Egypt, Arab Rep.', 'PPG, multilateral (DIS, current US$)', Decimal('2080241557.5')),
#  ('Bangladesh', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('2077014552.900000095')),
#  ('Pakistan', 'Interest payments on external debt, long-term (INT, current US$)', Decimal('2018025408.299999952')),
#  ('South Asia', 'PPG, bilateral (INT, current US$)', Decimal('2004917449.299999952')),
#  ('Turkey', 'PPG, official creditors (DIS, current US$)', Decimal('2004792977.5')),
#  ('Pakistan', 'PPG, bonds (AMT, current US$)', Decimal('2000000000')),
#  ('South Africa', 'PPG, bonds (AMT, current US$)', Decimal('2000000000')),
#  ('Jordan', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('1990343479.200000048')),
#  ('IDA only', 'PPG, private creditors (INT, current US$)', Decimal('1988140806.700000048')),
#  ('Dominican Republic', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('1978111141.200000048')),
#  ('Ukraine', 'PPG, bonds (AMT, current US$)', Decimal('1977107000')),
#  ('Pakistan', 'PPG, multilateral (DIS, current US$)', Decimal('1972944979.200000048')),
#  ('Morocco', 'Disbursements on external debt, long-term (DIS, current US$)', Decimal('1971794584.400000095')),
#  ('Brazil', 'PPG, multilateral (DIS, current US$)', Decimal('1949113519.799999952')),
#  ('Brazil', 'PPG, bonds (AMT, current US$)', Decimal('1940858500')),
#  ('South Asia', 'PPG, multilateral (INT, current US$)', Decimal('1915432943.799999952')),
#  ('Angola', 'PPG, private creditors (DIS, current US$)', Decimal('1906771593.799999952')),
#  ('Angola', 'PPG, commercial banks (DIS, current US$)', Decimal('1906771593.799999952')),
#  ('Ecuador', 'Interest payments on external debt, long-term (INT, current US$)', Decimal('1902464851.799999952')),
#  ('Morocco', 'PPG, official creditors (DIS, current US$)', Decimal('1893358239.599999905')),
#  ('Least developed countries: UN classification', 'PPG, private creditors (INT, current US$)', Decimal('1892298276.599999905')),
#  ('Bulgaria', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('1883205166.200000048')),
#  ('Romania', 'PPG, private creditors (AMT, current US$)', Decimal('1867927772.599999905')),
#  ('Brazil', 'PPG, commercial banks (INT, current US$)', Decimal('1846318920.200000048')),
#  ('Romania', 'PPG, official creditors (AMT, current US$)', Decimal('1845266582.099999905')),
#  ('Thailand', 'Interest payments on external debt, long-term (INT, current US$)', Decimal('1844227471.099999905')),
#  ('Kenya', 'PPG, multilateral (DIS, current US$)', Decimal('1840732714.299999952')),
#  ('Philippines', 'Interest payments on external debt, long-term (INT, current US$)', Decimal('1835490244.299999952')),
#  ('Tunisia', 'Disbursements on external debt, long-term (DIS, current US$)', Decimal('1820582243.5')),
#  ('Sri Lanka', 'Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)', Decimal('1805703222.200000048')),
#  ('Tunisia', 'PPG, official creditors (DIS, current US$)', Decimal('1802397015.700000048')),
#  ('Romania', 'PPG, bonds (AMT, current US$)', Decimal('1798950000')),
#  ('Angola', 'Interest payments on external debt, long-term (INT, current US$)', Decimal('1798550445.5')),
#  ('Romania', 'PPG, multilateral (AMT, current US$)', Decimal('1798305095.799999952')),
#  ('Romania', 'Interest payments on external debt, private nonguaranteed (PNG) (INT, current US$)', Decimal('1790450000')),
#  ('Costa Rica', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('1776491747.900000095')),
#  ('Mauritius', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('1757803962.200000048')),
#  ('Ecuador', 'PPG, official creditors (AMT, current US$)', Decimal('1756812536.5')),
#  ('IDA only', 'PPG, multilateral (INT, current US$)', Decimal('1755479051.599999905')),
#  ('Sri Lanka', 'PPG, bonds (AMT, current US$)', Decimal('1750000000')),
#  ('Sri Lanka', 'PPG, bilateral (DIS, current US$)', Decimal('1729975495.900000095')),
#  ('Peru', 'Disbursements on external debt, long-term (DIS, current US$)', Decimal('1701637273.299999952')),
#  ('Peru', 'PPG, official creditors (DIS, current US$)', Decimal('1701637273.299999952')),
#  ('Ghana', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('1689328833.5')),
#  ('Bosnia and Herzegovina', 'Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)', Decimal('1682608000')),
#  ('Senegal', 'Disbursements on external debt, long-term (DIS, current US$)', Decimal('1661790101.599999905')),
#  ('Lebanon', 'PPG, private creditors (INT, current US$)', Decimal('1652022762')),
#  ('Lebanon', 'PPG, bonds (INT, current US$)', Decimal('1649553000')),
#  ('Ukraine', 'Interest payments on external debt, private nonguaranteed (PNG) (INT, current US$)', Decimal('1647660000')),
#  ('Nigeria', 'PPG, official creditors (DIS, current US$)', Decimal('1642510515.700000048')),
#  ('Nigeria', 'Disbursements on external debt, long-term (DIS, current US$)', Decimal('1642510515.700000048')),
#  ('Peru', 'Interest payments on external debt, private nonguaranteed (PNG) (INT, current US$)', Decimal('1618289000')),
#  ('Bulgaria', 'Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)', Decimal('1618213900.200000048')),
#  ('Lao PDR', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('1605959990.099999905')),
#  ('Philippines', 'Disbursements on external debt, long-term (DIS, current US$)', Decimal('1599376586.299999952')),
#  ('Belarus', 'Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)', Decimal('1593265491.299999952')),
#  ('Turkey', 'PPG, multilateral (DIS, current US$)', Decimal('1589523902.099999905')),
#  ('Kenya', 'PPG, bilateral (DIS, current US$)', Decimal('1582905042')),
#  ('Pakistan', 'PPG, multilateral (AMT, current US$)', Decimal('1578651453.900000095')),
#  ('Peru', 'PPG, multilateral (DIS, current US$)', Decimal('1577764183.099999905')),
#  ('Mauritius', 'Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)', Decimal('1564598431.5')),
#  ('Vietnam', 'PPG, bilateral (AMT, current US$)', Decimal('1561158600.299999952')),
#  ('Pakistan', 'Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)', Decimal('1560240810')),
#  ('Georgia', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('1552116953.599999905')),
#  ('Colombia', 'PPG, official creditors (AMT, current US$)', Decimal('1548465447.700000048')),
#  ('Paraguay', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('1528508573.599999905')),
#  ('Turkey', 'PPG, commercial banks (AMT, current US$)', Decimal('1527243953.099999905')),
#  ('Uzbekistan', 'Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)', Decimal('1526555000')),
#  ('Sri Lanka', 'PPG, official creditors (AMT, current US$)', Decimal('1525209957.700000048')),
#  ('South Asia', 'PPG, bonds (INT, current US$)', Decimal('1515738709.799999952')),
#  ('Azerbaijan', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('1513813661.400000095')),
#  ('Morocco', 'PPG, multilateral (DIS, current US$)', Decimal('1512132928.200000048')),
#  ('Ghana', 'Disbursements on external debt, long-term (DIS, current US$)', Decimal('1508869861.5')),
#  ('Zambia', 'Disbursements on external debt, long-term (DIS, current US$)', Decimal('1502399702.799999952')),
#  ('Russian Federation', 'PPG, bonds (AMT, current US$)', Decimal('1500000000')),
#  ('Belarus', 'PPG, bilateral (AMT, current US$)', Decimal('1487363278.5')),
#  ('Egypt, Arab Rep.', 'Interest payments on external debt, long-term (INT, current US$)', Decimal('1480967451')),
#  ('Indonesia', 'PPG, other private creditors (AMT, current US$)', Decimal('1478184070.400000095')),
#  ('Tunisia', 'PPG, official creditors (AMT, current US$)', Decimal('1463656864.299999952')),
#  ('Mexico', 'PPG, commercial banks (AMT, current US$)', Decimal('1462493107.5')),
#  ('Kenya', 'PPG, private creditors (AMT, current US$)', Decimal('1450690438.200000048')),
#  ('Nigeria', 'PPG, multilateral (DIS, current US$)', Decimal('1444703185.099999905')),
#  ('Senegal', 'PPG, official creditors (DIS, current US$)', Decimal('1435396361.799999952')),
#  ('Bangladesh', 'PPG, official creditors (AMT, current US$)', Decimal('1426266902.5')),
#  ('Colombia', 'Interest payments on external debt, private nonguaranteed (PNG) (INT, current US$)', Decimal('1424280000')),
#  ('Bolivia', 'Disbursements on external debt, long-term (DIS, current US$)', Decimal('1421491255.200000048')),
#  ('Philippines', 'PPG, official creditors (AMT, current US$)', Decimal('1409531845.200000048')),
#  ('Bolivia', 'PPG, official creditors (DIS, current US$)', Decimal('1404962358.700000048')),
#  ('Least developed countries: UN classification', 'PPG, multilateral (INT, current US$)', Decimal('1396668176.299999952')),
#  ('Philippines', 'PPG, official creditors (DIS, current US$)', Decimal('1395548280.200000048')),
#  ('Serbia', 'Disbursements on external debt, long-term (DIS, current US$)', Decimal('1390127107.299999952')),
#  ('Tanzania', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('1388218481.400000095')),
#  ('Morocco', 'PPG, multilateral (AMT, current US$)', Decimal('1381649282.299999952')),
#  ('Romania', 'Disbursements on external debt, long-term (DIS, current US$)', Decimal('1381014186.299999952')),
#  ('Romania', 'PPG, official creditors (DIS, current US$)', Decimal('1380012530.900000095')),
#  ('China', 'PPG, official creditors (INT, current US$)', Decimal('1373305381.900000095')),
#  ('Dominican Republic', 'Interest payments on external debt, long-term (INT, current US$)', Decimal('1365524193.400000095')),
#  ('Uganda', 'Disbursements on external debt, long-term (DIS, current US$)', Decimal('1359705707.599999905')),
#  ('Thailand', 'Interest payments on external debt, private nonguaranteed (PNG) (INT, current US$)', Decimal('1347170000')),
#  ('Uganda', 'PPG, official creditors (DIS, current US$)', Decimal('1345018720')),
#  ('Ethiopia', 'PPG, multilateral (DIS, current US$)', Decimal('1344105921.599999905')),
#  ('Georgia', 'Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)', Decimal('1329982398.700000048')),
#  ('Ghana', 'PPG, official creditors (DIS, current US$)', Decimal('1327873653.099999905')),
#  ('Serbia', 'PPG, official creditors (DIS, current US$)', Decimal('1326485307.400000095')),
#  ('India', 'PPG, official creditors (INT, current US$)', Decimal('1318166051.599999905')),
#  ('IDA only', 'PPG, bonds (INT, current US$)', Decimal('1310931559.599999905')),
#  ('Ecuador', 'Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)', Decimal('1304435190')),
#  ('Sri Lanka', 'Interest payments on external debt, long-term (INT, current US$)', Decimal('1304221181.400000095')),
#  ('El Salvador', 'PPG, private creditors (AMT, current US$)', Decimal('1271830068')),
#  ('Romania', 'PPG, multilateral (DIS, current US$)', Decimal('1264945613.099999905')),
#  ('El Salvador', 'PPG, bonds (AMT, current US$)', Decimal('1259866714.299999952')),
#  ('Mexico', 'PPG, official creditors (AMT, current US$)', Decimal('1246639102.599999905')),
#  ('Myanmar', 'Disbursements on external debt, long-term (DIS, current US$)', Decimal('1246429044.299999952')),
#  ('Myanmar', 'PPG, official creditors (DIS, current US$)', Decimal('1246429044.299999952')),
#  ('Paraguay', 'Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)', Decimal('1243177380')),
#  ('Uzbekistan', 'Disbursements on external debt, long-term (DIS, current US$)', Decimal('1239046975.099999905')),
#  ('Uzbekistan', 'PPG, official creditors (DIS, current US$)', Decimal('1239046975.099999905')),
#  ('China', 'PPG, bonds (INT, current US$)', Decimal('1224249000')),
#  ('Zambia', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('1217643471.900000095')),
#  ('Belarus', 'Interest payments on external debt, long-term (INT, current US$)', Decimal('1214489897.099999905')),
#  ('Indonesia', 'PPG, multilateral (DIS, current US$)', Decimal('1214274597.200000048')),
#  ('Least developed countries: UN classification', 'PPG, bonds (AMT, current US$)', Decimal('1203368516.900000095')),
#  ('Pakistan', 'PPG, official creditors (INT, current US$)', Decimal('1195133408.299999952')),
#  ('Ethiopia', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('1188923977.599999905')),
#  ('Dominican Republic', 'Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)', Decimal('1186278905')),
#  ('Nicaragua', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('1185575296.799999952')),
#  ('Ukraine', 'PPG, private creditors (INT, current US$)', Decimal('1180164511')),
#  ('Brazil', 'PPG, bilateral (DIS, current US$)', Decimal('1179125278.799999952')),
#  ('IDA only', 'PPG, private creditors (DIS, current US$)', Decimal('1178192946.299999952')),
#  ('Ecuador', 'PPG, bilateral (AMT, current US$)', Decimal('1177917742.599999905')),
#  ('Ukraine', 'PPG, bonds (INT, current US$)', Decimal('1176828000')),
#  ('Nigeria', 'Interest payments on external debt, long-term (INT, current US$)', Decimal('1174953817.599999905')),
#  ('IDA only', 'Interest payments on external debt, private nonguaranteed (PNG) (INT, current US$)', Decimal('1174413339.700000048')),
#  ('Philippines', 'PPG, private creditors (AMT, current US$)', Decimal('1170001612.599999905')),
#  ('Ukraine', 'PPG, official creditors (AMT, current US$)', Decimal('1168414049.700000048')),
#  ('Tanzania', 'PPG, official creditors (DIS, current US$)', Decimal('1166055814.5')),
#  ('Tanzania', 'Disbursements on external debt, long-term (DIS, current US$)', Decimal('1166055814.5')),
#  ('Ghana', 'PPG, bilateral (DIS, current US$)', Decimal('1163413713.799999952')),
#  ('Ethiopia', 'PPG, bilateral (DIS, current US$)', Decimal('1142444763.299999952')),
#  ('Lao PDR', 'Disbursements on external debt, long-term (DIS, current US$)', Decimal('1135545159.799999952')),
#  ('India', 'PPG, bonds (AMT, current US$)', Decimal('1133333333.299999952')),
#  ('Colombia', 'PPG, commercial banks (AMT, current US$)', Decimal('1129332984.299999952')),
#  ('Angola', 'PPG, commercial banks (AMT, current US$)', Decimal('1125088719.900000095')),
#  ('Kazakhstan', 'PPG, official creditors (AMT, current US$)', Decimal('1124733386.400000095')),
#  ('Costa Rica', 'Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)', Decimal('1118456384.400000095')),
#  ('Venezuela, RB', 'Interest payments on external debt, private nonguaranteed (PNG) (INT, current US$)', Decimal('1111403000')),
#  ('Zambia', 'PPG, official creditors (DIS, current US$)', Decimal('1103672288.799999952')),
#  ('Colombia', 'PPG, multilateral (AMT, current US$)', Decimal('1100907553.599999905')),
#  ('Lao PDR', 'PPG, official creditors (DIS, current US$)', Decimal('1097399289.400000095')),
#  ('Azerbaijan', 'Disbursements on external debt, long-term (DIS, current US$)', Decimal('1088458061.200000048')),
#  ('Serbia', 'Interest payments on external debt, long-term (INT, current US$)', Decimal('1087126443.299999952')),
#  ("Cote d'Ivoire", 'Disbursements on external debt, long-term (DIS, current US$)', Decimal('1081936422.799999952')),
#  ("Cote d'Ivoire", 'PPG, official creditors (DIS, current US$)', Decimal('1081936422.799999952')),
#  ('Kazakhstan', 'PPG, multilateral (AMT, current US$)', Decimal('1079948889.700000048')),
#  ('Sri Lanka', 'PPG, bilateral (AMT, current US$)', Decimal('1075437996.599999905')),
#  ('Ukraine', 'PPG, multilateral (AMT, current US$)', Decimal('1072472830.299999952')),
#  ('Bolivia', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('1060650554.5')),
#  ('Angola', 'PPG, official creditors (INT, current US$)', Decimal('1052092441.200000048')),
#  ('Jordan', 'PPG, private creditors (AMT, current US$)', Decimal('1044261486.5')),
#  ('Serbia', 'PPG, official creditors (AMT, current US$)', Decimal('1043951488.299999952')),
#  ('Bangladesh', 'PPG, multilateral (AMT, current US$)', Decimal('1039564682.700000048')),
#  ('Brazil', 'PPG, official creditors (INT, current US$)', Decimal('1039267125.799999952')),
#  ('Indonesia', 'PPG, official creditors (INT, current US$)', Decimal('1038590196.299999952')),
#  ('Costa Rica', 'Interest payments on external debt, long-term (INT, current US$)', Decimal('1031562783.399999976')),
#  ('Jordan', 'PPG, bonds (AMT, current US$)', Decimal('1029000000')),
#  ('Ecuador', 'PPG, private creditors (INT, current US$)', Decimal('1017912486.5')),
#  ('Tanzania', 'PPG, multilateral (DIS, current US$)', Decimal('1015707138.5')),
#  ('Bulgaria', 'Interest payments on external debt, long-term (INT, current US$)', Decimal('1012039083.100000024')),
#  ('Angola', 'PPG, bilateral (INT, current US$)', Decimal('1005053965.100000024')),
#  ('Angola', 'PPG, bonds (AMT, current US$)', Decimal('1000000000')),
#  ('Ghana', 'PPG, official creditors (AMT, current US$)', Decimal('996094041.799999952')),
#  ('India', 'PPG, private creditors (INT, current US$)', Decimal('989848814.200000048')),
#  ('Morocco', 'Interest payments on external debt, long-term (INT, current US$)', Decimal('988479361.5')),
#  ("Cote d'Ivoire", 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('979241934.399999976')),
#  ('Indonesia', 'PPG, commercial banks (AMT, current US$)', Decimal('977304350')),
#  ('China', 'PPG, commercial banks (INT, current US$)', Decimal('969933090')),
#  ('Nicaragua', 'Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)', Decimal('969200000')),
#  ('Pakistan', 'PPG, commercial banks (AMT, current US$)', Decimal('968637742.899999976')),
#  ('Lao PDR', 'PPG, bilateral (DIS, current US$)', Decimal('966004791.100000024')),
#  ('Vietnam', 'Interest payments on external debt, private nonguaranteed (PNG) (INT, current US$)', Decimal('965351000')),
#  ('Brazil', 'PPG, private creditors (DIS, current US$)', Decimal('964149852.799999952')),
#  ('Brazil', 'PPG, commercial banks (DIS, current US$)', Decimal('964149852.799999952')),
#  ('Belarus', 'PPG, private creditors (AMT, current US$)', Decimal('963970288.399999976')),
#  ('El Salvador', 'Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)', Decimal('957598000')),
#  ('South Africa', 'Interest payments on external debt, private nonguaranteed (PNG) (INT, current US$)', Decimal('957111168.5')),
#  ('Tunisia', 'PPG, multilateral (AMT, current US$)', Decimal('956604000.100000024')),
#  ('Vietnam', 'PPG, multilateral (AMT, current US$)', Decimal('947632152.5')),
#  ('Tunisia', 'PPG, multilateral (DIS, current US$)', Decimal('947210895.799999952')),
#  ('Lao PDR', 'Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)', Decimal('940602190')),
#  ('Belarus', 'PPG, commercial banks (AMT, current US$)', Decimal('935058288.399999976')),
#  ('Romania', 'PPG, private creditors (INT, current US$)', Decimal('924157529')),
#  ('Least developed countries: UN classification', 'PPG, commercial banks (INT, current US$)', Decimal('917218236.600000024')),
#  ('Romania', 'PPG, bonds (INT, current US$)', Decimal('917027107.299999952')),
#  ('IDA only', 'PPG, commercial banks (DIS, current US$)', Decimal('909245034.700000048')),
#  ('Vietnam', 'PPG, official creditors (INT, current US$)', Decimal('908503259.600000024')),
#  ('Kenya', 'PPG, official creditors (AMT, current US$)', Decimal('906442158')),
#  ('Philippines', 'PPG, bonds (AMT, current US$)', Decimal('903941000')),
#  ('Kenya', 'PPG, commercial banks (AMT, current US$)', Decimal('897058411.600000024')),
#  ('Senegal', 'PPG, multilateral (DIS, current US$)', Decimal('886747852.700000048')),
#  ('Mongolia', 'Interest payments on external debt, long-term (INT, current US$)', Decimal('877048982.5')),
#  ('Macedonia, FYR', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('875846538.5')),
#  ('Kazakhstan', 'PPG, official creditors (DIS, current US$)', Decimal('874231247')),
#  ('Kazakhstan', 'Disbursements on external debt, long-term (DIS, current US$)', Decimal('874231247')),
#  ('Ghana', 'PPG, bilateral (AMT, current US$)', Decimal('865892038.700000048')),
#  ('Mexico', 'PPG, multilateral (AMT, current US$)', Decimal('864181883.5')),
#  ('India', 'PPG, multilateral (INT, current US$)', Decimal('862200894')),
#  ('China', 'PPG, multilateral (INT, current US$)', Decimal('858406974.799999952')),
#  ('Tunisia', 'PPG, bilateral (DIS, current US$)', Decimal('855186119.899999976')),
#  ('Nepal', 'PPG, official creditors (DIS, current US$)', Decimal('854955604')),
#  ('Nepal', 'Disbursements on external debt, long-term (DIS, current US$)', Decimal('854955604')),
#  ('Philippines', 'PPG, multilateral (DIS, current US$)', Decimal('851399752.399999976')),
#  ('Bolivia', 'PPG, multilateral (DIS, current US$)', Decimal('850833672.399999976')),
#  ('Cameroon', 'PPG, multilateral (DIS, current US$)', Decimal('850036788.100000024')),
#  ('Armenia', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('845630723.799999952')),
#  ('Kenya', 'PPG, private creditors (DIS, current US$)', Decimal('842857183.399999976')),
#  ('Kenya', 'PPG, commercial banks (DIS, current US$)', Decimal('842857183.399999976')),
#  ('Kyrgyz Republic', 'Disbursements on external debt, long-term (DIS, current US$)', Decimal('837442293.399999976')),
#  ('Kyrgyz Republic', 'PPG, official creditors (DIS, current US$)', Decimal('837442293.399999976')),
#  ('Peru', 'PPG, private creditors (INT, current US$)', Decimal('834211575')),
#  ('Peru', 'PPG, bonds (INT, current US$)', Decimal('834211575')),
# ...
#  ('Armenia', 'Interest payments on external debt, long-term (INT, current US$)', Decimal('275292981.100000024')),
#  ('Mozambique', 'PPG, multilateral (DIS, current US$)', Decimal('275120256.100000024')),
#  ('Azerbaijan', 'PPG, private creditors (INT, current US$)', Decimal('274885780.199999988')),
#  ('Uzbekistan', 'PPG, bilateral (AMT, current US$)', Decimal('273378640')),
#  ('Costa Rica', 'PPG, multilateral (AMT, current US$)', Decimal('272808260.699999988')),
#  ('Papua New Guinea', 'PPG, bilateral (DIS, current US$)', Decimal('272745704.399999976')),
#  ('Belarus', 'Interest payments on external debt, private nonguaranteed (PNG) (INT, current US$)', Decimal('272640306.399999976')),
#  ('Honduras', 'Disbursements on external debt, long-term (DIS, current US$)', Decimal('271661829.800000012')),
#  ('Morocco', 'PPG, bonds (INT, current US$)', Decimal('270530500')),
#  ('Jordan', 'PPG, multilateral (AMT, current US$)', Decimal('270498715.5')),
#  ('Sri Lanka', 'PPG, bilateral (INT, current US$)', Decimal('270096709.899999976')),
#  ('Benin', 'PPG, multilateral (DIS, current US$)', Decimal('269747441.199999988')),
#  ('IDA only', 'PPG, other private creditors (DIS, current US$)', Decimal('268947911.600000024')),
#  ('Sri Lanka', 'Interest payments on external debt, private nonguaranteed (PNG) (INT, current US$)', Decimal('268295000')),
#  ('Jamaica', 'PPG, official creditors (AMT, current US$)', Decimal('268161320.099999994')),
#  ('Congo, Dem. Rep.', 'PPG, multilateral (DIS, current US$)', Decimal('267059597.599999994')),
#  ('Syrian Arab Republic', 'Disbursements on external debt, long-term (DIS, current US$)', Decimal('266925460.400000006')),
#  ('Syrian Arab Republic', 'PPG, official creditors (DIS, current US$)', Decimal('266925460.400000006')),
#  ('Senegal', 'Interest payments on external debt, long-term (INT, current US$)', Decimal('266493300.400000006')),
#  ('Pakistan', 'Interest payments on external debt, private nonguaranteed (PNG) (INT, current US$)', Decimal('266062000')),
#  ('Paraguay', 'PPG, official creditors (AMT, current US$)', Decimal('265976193.599999994')),
#  ('Least developed countries: UN classification', 'PPG, other private creditors (DIS, current US$)', Decimal('264891046.5')),
#  ('Bulgaria', 'PPG, official creditors (AMT, current US$)', Decimal('264757222.599999994')),
#  ('Zambia', 'PPG, official creditors (AMT, current US$)', Decimal('264117339.199999988')),
#  ('Sudan', 'PPG, bilateral (AMT, current US$)', Decimal('262918897.800000012')),
#  ('Mauritania', 'PPG, bilateral (DIS, current US$)', Decimal('262893890.199999988')),
#  ('Honduras', 'PPG, official creditors (DIS, current US$)', Decimal('260558926.300000012')),
#  ('Uzbekistan', 'Interest payments on external debt, private nonguaranteed (PNG) (INT, current US$)', Decimal('260318000')),
#  ('Congo, Dem. Rep.', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('259836541.400000006')),
#  ('Congo, Dem. Rep.', 'PPG, official creditors (AMT, current US$)', Decimal('259557791.400000006')),
#  ('Rwanda', 'PPG, multilateral (DIS, current US$)', Decimal('258162028.300000012')),
#  ('Macedonia, FYR', 'PPG, official creditors (AMT, current US$)', Decimal('256523417.5')),
#  ('Dominican Republic', 'PPG, multilateral (AMT, current US$)', Decimal('254728306.099999994')),
#  ('Philippines', 'PPG, multilateral (INT, current US$)', Decimal('254559486.900000006')),
#  ('Kazakhstan', 'PPG, bilateral (DIS, current US$)', Decimal('254112169.300000012')),
#  ('Bosnia and Herzegovina', 'Disbursements on external debt, long-term (DIS, current US$)', Decimal('253819587.300000012')),
#  ('Bosnia and Herzegovina', 'PPG, official creditors (DIS, current US$)', Decimal('253819587.300000012')),
#  ('Armenia', 'PPG, multilateral (DIS, current US$)', Decimal('252689328.900000006')),
#  ('South Africa', 'PPG, official creditors (DIS, current US$)', Decimal('251984484.5')),
#  ('South Africa', 'PPG, multilateral (DIS, current US$)', Decimal('251984484.5')),
#  ('Tunisia', 'PPG, private creditors (INT, current US$)', Decimal('251241562.699999988')),
#  ('Montenegro', 'PPG, official creditors (DIS, current US$)', Decimal('251048938.5')),
#  ('Montenegro', 'Disbursements on external debt, long-term (DIS, current US$)', Decimal('251048938.5')),
#  ('Serbia', 'PPG, official creditors (INT, current US$)', Decimal('249341616.400000006')),
#  ('Serbia', 'PPG, private creditors (INT, current US$)', Decimal('248578495.300000012')),
#  ('Congo, Rep.', 'PPG, official creditors (DIS, current US$)', Decimal('247432137.699999988')),
#  ('Congo, Rep.', 'Disbursements on external debt, long-term (DIS, current US$)', Decimal('247432137.699999988')),
#  ('Vietnam', 'PPG, private creditors (INT, current US$)', Decimal('246239476.699999988')),
#  ('Cameroon', 'PPG, private creditors (DIS, current US$)', Decimal('246081024.800000012')),
#  ('Honduras', 'Interest payments on external debt, long-term (INT, current US$)', Decimal('245990147.300000012')),
#  ('El Salvador', 'Disbursements on external debt, long-term (DIS, current US$)', Decimal('245967023.199999988')),
#  ('Uzbekistan', 'PPG, multilateral (AMT, current US$)', Decimal('244240575.599999994')),
#  ('IDA only', 'PPG, other private creditors (INT, current US$)', Decimal('244238305.300000012')),
#  ('Belarus', 'PPG, multilateral (DIS, current US$)', Decimal('241493806')),
#  ('Myanmar', 'Interest payments on external debt, long-term (INT, current US$)', Decimal('240557887.699999988')),
#  ('Madagascar', 'PPG, multilateral (DIS, current US$)', Decimal('240358091.599999994')),
#  ('Tunisia', 'PPG, bonds (INT, current US$)', Decimal('238989390.099999994')),
#  ('Myanmar', 'PPG, official creditors (INT, current US$)', Decimal('238945887.699999988')),
#  ('Serbia', 'PPG, bonds (INT, current US$)', Decimal('238124000')),
#  ('Lao PDR', 'PPG, private creditors (AMT, current US$)', Decimal('237811743.300000012')),
#  ('Ecuador', 'PPG, multilateral (INT, current US$)', Decimal('237657740.5')),
#  ('Zambia', 'PPG, bonds (INT, current US$)', Decimal('237436000')),
#  ('Togo', 'PPG, official creditors (DIS, current US$)', Decimal('236837922.900000006')),
#  ('Togo', 'Disbursements on external debt, long-term (DIS, current US$)', Decimal('236837922.900000006')),
#  ('Albania', 'PPG, official creditors (AMT, current US$)', Decimal('236447897.300000012')),
#  ('Albania', 'PPG, multilateral (DIS, current US$)', Decimal('234321242.300000012')),
#  ('Kosovo', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('232317825.800000012')),
#  ('Jordan', 'PPG, bilateral (AMT, current US$)', Decimal('230204467.199999988')),
#  ('Maldives', 'PPG, official creditors (DIS, current US$)', Decimal('229394093.300000012')),
#  ('Bulgaria', 'PPG, multilateral (AMT, current US$)', Decimal('228993019.800000012')),
#  ('Senegal', 'PPG, private creditors (DIS, current US$)', Decimal('226393739.800000012')),
#  ('Congo, Rep.', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('225882395.599999994')),
#  ('Azerbaijan', 'PPG, bonds (INT, current US$)', Decimal('225022000')),
#  ('Egypt, Arab Rep.', 'PPG, private creditors (AMT, current US$)', Decimal('223363381.099999994')),
#  ('Cambodia', 'PPG, bilateral (AMT, current US$)', Decimal('223300273.599999994')),
#  ('Egypt, Arab Rep.', 'PPG, commercial banks (AMT, current US$)', Decimal('222817364.800000012')),
#  ('Ecuador', 'Interest payments on external debt, private nonguaranteed (PNG) (INT, current US$)', Decimal('222441000')),
#  ('Uganda', 'Interest payments on external debt, long-term (INT, current US$)', Decimal('221400672.800000012')),
#  ('Mongolia', 'PPG, private creditors (INT, current US$)', Decimal('220935674.5')),
#  ('Yemen, Rep.', 'PPG, multilateral (AMT, current US$)', Decimal('220743129.900000006')),
#  ('Macedonia, FYR', 'Interest payments on external debt, long-term (INT, current US$)', Decimal('220478984.099999994')),
#  ('Nepal', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('220142894.400000006')),
#  ('Turkey', 'PPG, commercial banks (INT, current US$)', Decimal('220044039.800000012')),
#  ('Venezuela, RB', 'PPG, official creditors (INT, current US$)', Decimal('220000907.199999988')),
#  ('South Asia', 'PPG, private creditors (DIS, current US$)', Decimal('219553713.199999988')),
#  ('South Asia', 'PPG, commercial banks (DIS, current US$)', Decimal('219553713.199999988')),
#  ('Indonesia', 'PPG, other private creditors (DIS, current US$)', Decimal('218075500')),
#  ('Myanmar', 'PPG, bilateral (INT, current US$)', Decimal('217742156')),
#  ('Sudan', 'PPG, multilateral (AMT, current US$)', Decimal('217194878.800000012')),
#  ('Kazakhstan', 'PPG, official creditors (INT, current US$)', Decimal('217076397.900000006')),
#  ('Mali', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('216102639.5')),
#  ('Mali', 'PPG, official creditors (AMT, current US$)', Decimal('216034519.300000012')),
#  ('Philippines', 'PPG, commercial banks (AMT, current US$)', Decimal('215119588.099999994')),
#  ('Nicaragua', 'PPG, official creditors (AMT, current US$)', Decimal('214530576.5')),
#  ('Dominican Republic', 'PPG, bilateral (AMT, current US$)', Decimal('214014574.599999994')),
#  ('Mongolia', 'PPG, multilateral (DIS, current US$)', Decimal('213960781.699999988')),
#  ('Bhutan', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('213258536.900000006')),
#  ('Nepal', 'PPG, official creditors (AMT, current US$)', Decimal('212259894.400000006')),
#  ('Ethiopia', 'PPG, other private creditors (AMT, current US$)', Decimal('212179959.599999994')),
#  ('Russian Federation', 'PPG, official creditors (AMT, current US$)', Decimal('211593722.199999988')),
#  ('Nepal', 'PPG, bilateral (DIS, current US$)', Decimal('211256468.099999994')),
#  ('Zambia', 'PPG, bilateral (AMT, current US$)', Decimal('211048374.300000012')),
#  ('Honduras', 'Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)', Decimal('210406059.699999988')),
#  ('Uganda', 'PPG, official creditors (AMT, current US$)', Decimal('209420418.400000006')),
#  ('Gabon', 'Interest payments on external debt, long-term (INT, current US$)', Decimal('209330192.900000006')),
#  ('Georgia', 'PPG, official creditors (AMT, current US$)', Decimal('207893813.599999994')),
#  ('South Asia', 'PPG, other private creditors (AMT, current US$)', Decimal('207766207.599999994')),
#  ('Paraguay', 'PPG, multilateral (AMT, current US$)', Decimal('207662030.900000006')),
#  ('Ecuador', 'PPG, commercial banks (INT, current US$)', Decimal('207314486.5')),
#  ('Bhutan', 'PPG, official creditors (AMT, current US$)', Decimal('207268290.300000012')),
#  ('Chad', 'Disbursements on external debt, long-term (DIS, current US$)', Decimal('207090418.300000012')),
#  ('Chad', 'PPG, official creditors (DIS, current US$)', Decimal('207090418.300000012')),
#  ('Venezuela, RB', 'PPG, multilateral (INT, current US$)', Decimal('206837690.900000006')),
#  ('Montenegro', 'PPG, official creditors (AMT, current US$)', Decimal('205398217.699999988')),
#  ('Bulgaria', 'PPG, private creditors (INT, current US$)', Decimal('204409891.300000012')),
#  ('Bulgaria', 'PPG, bonds (INT, current US$)', Decimal('204322342.400000006')),
#  ('Congo, Rep.', 'PPG, official creditors (AMT, current US$)', Decimal('204185967.099999994')),
#  ('Philippines', 'PPG, private creditors (DIS, current US$)', Decimal('203828306.099999994')),
#  ('Lao PDR', 'PPG, bonds (AMT, current US$)', Decimal('203368516.900000006')),
#  ('Mozambique', 'PPG, private creditors (AMT, current US$)', Decimal('203259684.599999994')),
#  ('Mongolia', 'PPG, bonds (INT, current US$)', Decimal('203124000')),
#  ('Madagascar', 'PPG, bilateral (DIS, current US$)', Decimal('201529156.099999994')),
#  ('Bhutan', 'Interest payments on external debt, long-term (INT, current US$)', Decimal('201006184.099999994')),
#  ('Mozambique', 'PPG, commercial banks (AMT, current US$)', Decimal('200988925.699999988')),
#  ('Nigeria', 'PPG, bilateral (DIS, current US$)', Decimal('197807330.599999994')),
#  ('Mauritania', 'PPG, bilateral (AMT, current US$)', Decimal('197041185.099999994')),
#  ('Egypt, Arab Rep.', 'PPG, commercial banks (DIS, current US$)', Decimal('196463721.599999994')),
#  ('Egypt, Arab Rep.', 'PPG, private creditors (DIS, current US$)', Decimal('196463721.599999994')),
#  ('Cameroon', 'PPG, commercial banks (DIS, current US$)', Decimal('196167124.800000012')),
#  ('Tanzania', 'PPG, bilateral (AMT, current US$)', Decimal('194944695.300000012')),
#  ('Ethiopia', 'PPG, private creditors (DIS, current US$)', Decimal('194942322.400000006')),
#  ('Tunisia', 'PPG, multilateral (INT, current US$)', Decimal('193716342.400000006')),
#  ('Bhutan', 'PPG, official creditors (INT, current US$)', Decimal('192953907.800000012')),
#  ('Nigeria', 'PPG, official creditors (INT, current US$)', Decimal('192447817.599999994')),
#  ('Romania', 'PPG, official creditors (INT, current US$)', Decimal('192267765.599999994')),
#  ('Kosovo', 'Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)', Decimal('190945000')),
#  ('Bhutan', 'PPG, bilateral (AMT, current US$)', Decimal('189877869.800000012')),
#  ('Jamaica', 'PPG, official creditors (DIS, current US$)', Decimal('188717385.699999988')),
#  ('Jamaica', 'Disbursements on external debt, long-term (DIS, current US$)', Decimal('188717385.699999988')),
#  ('Moldova', 'PPG, official creditors (AMT, current US$)', Decimal('188299076.099999994')),
#  ('Mauritius', 'PPG, official creditors (AMT, current US$)', Decimal('187743318.800000012')),
#  ('Bolivia', 'PPG, official creditors (INT, current US$)', Decimal('187586589')),
#  ('Dominican Republic', 'PPG, multilateral (DIS, current US$)', Decimal('186149762.400000006')),
#  ('Congo, Rep.', 'PPG, bilateral (AMT, current US$)', Decimal('186071498.099999994')),
#  ('Macedonia, FYR', 'PPG, multilateral (AMT, current US$)', Decimal('185952867.199999988')),
#  ('Mozambique', 'Interest payments on external debt, long-term (INT, current US$)', Decimal('184653722.699999988')),
#  ('Mauritania', 'PPG, multilateral (AMT, current US$)', Decimal('184408220.199999988')),
#  ('Romania', 'PPG, multilateral (INT, current US$)', Decimal('184253287.199999988')),
#  ('Honduras', 'PPG, official creditors (AMT, current US$)', Decimal('184115800.599999994')),
#  ('Bhutan', 'PPG, bilateral (INT, current US$)', Decimal('184064524.800000012')),
#  ('Kenya', 'PPG, bonds (INT, current US$)', Decimal('184060000')),
#  ('Cambodia', 'Interest payments on external debt, long-term (INT, current US$)', Decimal('183222625.400000006')),
#  ('Lao PDR', 'Interest payments on external debt, private nonguaranteed (PNG) (INT, current US$)', Decimal('183013000')),
#  ('Albania', 'PPG, multilateral (AMT, current US$)', Decimal('182197616.699999988')),
#  ('Nicaragua', 'PPG, multilateral (AMT, current US$)', Decimal('181115898')),
#  ('Paraguay', 'Interest payments on external debt, private nonguaranteed (PNG) (INT, current US$)', Decimal('181087000')),
#  ('Ghana', 'PPG, private creditors (DIS, current US$)', Decimal('180996208.400000006')),
#  ('Ghana', 'PPG, commercial banks (DIS, current US$)', Decimal('180680823.300000012')),
#  ('Vietnam', 'PPG, commercial banks (INT, current US$)', Decimal('180617476.699999988')),
#  ('Macedonia, FYR', 'PPG, multilateral (DIS, current US$)', Decimal('180178623.900000006')),
#  ('Chad', 'PPG, multilateral (DIS, current US$)', Decimal('179102757.400000006')),
#  ('Angola', 'PPG, multilateral (DIS, current US$)', Decimal('178989598.199999988')),
#  ('Belarus', 'PPG, private creditors (INT, current US$)', Decimal('178588095.900000006')),
#  ('Chad', 'Principal repayments on external debt, long-term (AMT, current US$)', Decimal('178106958')),
#  ('Chad', 'PPG, official creditors (AMT, current US$)', Decimal('178095924.400000006')),
#  ('Gabon', 'PPG, official creditors (AMT, current US$)', Decimal('177101208.300000012')),
#  ('Djibouti', 'Disbursements on external debt, long-term (DIS, current US$)', Decimal('176522478.199999988')),
#  ('Djibouti', 'PPG, official creditors (DIS, current US$)', Decimal('176522478.199999988')),
#  ...]
